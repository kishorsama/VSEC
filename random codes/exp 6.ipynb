# %%
import pandas as pd
import matplotlib.pyplot as pt
import seaborn as sns

# %%
from sklearn.datasets import load_iris
iris = load_iris()

# %%
df = pd.DataFrame(iris.data, columns=iris.feature_names)
df.hist(figsize=(15,8), bins=30, color='grey', edgecolor='black')

pt.suptitle("Histogram of iris dataset", fontsize=20)
pt.show()
